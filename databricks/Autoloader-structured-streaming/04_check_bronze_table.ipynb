# %%
# Step 05 - Check Bronze table

catalog = "retail"
schema = "sales"

table_name = f"{catalog}.{schema}.orders_bronze"

display(spark.table(table_name))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>amount</th><th>customer</th><th>order_id</th><th>_rescued_data</th></tr></thead><tbody><tr><td>250</td><td>Aditi</td><td>1</td><td>null</td></tr><tr><td>120</td><td>Rahul</td><td>2</td><td>null</td></tr><tr><td>890</td><td>Meera</td><td>3</td><td>null</td></tr><tr><td>410</td><td>Sanjay</td><td>4</td><td>null</td></tr></tbody></table></div>
