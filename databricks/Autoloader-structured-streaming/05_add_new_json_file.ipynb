# %%
# Step 06 - Add a new JSON file

catalog = "retail"
schema = "sales"
volume = "autoloader_demo"

landing = f"/Volumes/{catalog}/{schema}/{volume}/auto_loader/landing"

dbutils.fs.put(
    f"{landing}/orders_03.json",
    '{"order_id": 4, "customer": "Sanjay", "amount": 410}\n',
    True
)

print("New JSON file added.")
# Out:
# Wrote 53 bytes.
# New JSON file added.
