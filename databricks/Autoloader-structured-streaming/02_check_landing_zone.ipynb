# %%
# Step 02 - Check the landing zone

catalog = "retail"
schema = "sales"
volume = "autoloader_demo"

landing = f"/Volumes/{catalog}/{schema}/{volume}/auto_loader/landing"

# Display files currently available in the landing zone
display(dbutils.fs.ls(landing))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/retail/sales/autoloader_demo/auto_loader/landing/orders_01.json</td><td>orders_01.json</td><td>104</td><td>1790350531000</td></tr><tr><td>dbfs:/Volumes/retail/sales/autoloader_demo/auto_loader/landing/orders_02.json</td><td>orders_02.json</td><td>52</td><td>1790350532000</td></tr></tbody></table></div>
