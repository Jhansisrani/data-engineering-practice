# %%
 

def fn_grtst_no(a,b,c,d,e):
     #a =  5000
     #b = 77
     #c = 10000
     #d = 980
     #e = 110
 
     if a >=b and a>=c and a>=d and a>=e:#  if a is the largest
         
         print(a, "is the first largest") #print a.. if its true, it goes next if statement..if fails exit from this loop goes to else if.
         
         
         if b>=c and b>=d and b>=e: #b if b is the sec largest 
            print(b ,"is the second largest")    #print b  .it goes next if statement  .if fails goes next elseif   
            if c>=d and c>=e:                      #if c is the third largest,true
             print(c ,"is the third largest number") #print c ,if fail goes to next else if
            elif d>=e:                                # if d is the third largest
             print(d ,"is the third largest number") #print d. else go to next  else
            else: 
             print(e,"is the third greatest number") #print e .is the third largest
         elif c>=d and c>=e:                           #if b fails,it checks c is the sec largest.
             print (c ,"is the second largest") 
             if b>=d and b>=e:
              print(b ,"is the third largest number")
             elif d>=e:
              print(d ,"is the third largest number")
             else:
              print(e,"is the third greatest number")         
            
         elif d>=e:
             print (d ,"is the second largest")
             if b>=c and b>=e:
               print(b,"is the third largest number")
             elif c>=e:
                print(c,"is the third largest number")
             else:
                print(e,"is the third largest number")
         else:
              print(e, "is the second largest")
        
              if b>=c and b>=d:           
               print(b,"is the third greatest no")
              elif c>=d and c>=b: #c
               print(c,"is the third greatest no")
              else:
               print(d,"is the third greatest number")
           
         
         
     elif b>=a and b>=c  and b>=d and b>=e: #b
         print (b, "is the first greatest no")          
           
         if a>=c and a>=d and a>=e:#a
            print(a ,"is the second largest")
            if c>=d and c>=e:
              print (c ,"is the third largest")
            elif d>=c and d>=e:
              print (d ,"is the third largest")
            else:
              print(e, "is the third largest number")
         elif c>=d and c>=e:
           print (c ,"is the second largest")
           if a>=d and a>=e:
             print(a,"is the third greatest number")
           elif d>=e:
             print(d,"is the third largest number")
           else:
             print(e, "is the third largest number")
         elif d>=e:
             print (d ,"is the second largest")
             if a>=b and a>=c:
              print(a,"is the third greatest number")
             elif b>=c:
              print(b,"is the third greatest number")
             else:
              print(e,"is the third greatest number")
            
         else:
          print(e, "is the second largest")
          if a>=c and a>=d:
            print(a,"is the third largest number")
          elif c>=d:
            print (c,"is the third largest number")
          else:
            print (d,"is the third largest number")
      
              
         
     elif c>=a and c>=b and c>=d and c>=e: #c
         print(c ," is the first greatest no") 
     
       
         if a>=b and a>=d and a>=e: #a
           print(a ,"is the second largest")
           if b>=d and b>=e:
             print (b,"is the third greatest no")
           elif d>=e:
             print (d,"is the third greatest no")
           else:
             print(e, "is the third largest")
         elif b>=d and b>=e:
           print (b ,"is the second largest")  
           if a>=d and a>=e:
             print(a,"is the third largest number")
           elif d>=e:
             print(d,"is the third largest number")
           else:
             print(e,"is the third largest number")
         elif d>=e:
            print (d ,"is the second largest")
            if a>=b and a>=e:
              print(a,"is the third largest number")
            elif b>=e:
              print(b,"is the third largest number")
            else:
              print(e, "is the third largest number")         
          
         else:
           print(e, "is the second largest")
           if a>=b and a>=d:
            print(a,"is the third largest number")
           elif b>=c:
             print(c,"is the third largest number")
           else:
             print(d,"is the third largest number")
           
        
              
            
     elif d>=a and d>=b and d>=c and d>=e: #d
         print (d,  " is the first Greatest no")
         largest_first=d
         if a>=b and a>=c and a>=e: #a
            print(a ,"is the second largest")    
            if b>=c and b>=e:
              print(b, "is the third largest no") 
            elif c>=e:
              print(c,"is the third largest number")
            else:
              print(e,"is the third largest no")    
         elif b>=c and b>=e:
           print (b ,"is the second largestt")
           if a>=c and a>=e:
             print(a,"is the third largest no")
           elif c>=e:
             print(c,"is the third largest no")
           else:
             print(e,"is the third largest no")
         elif c>=e:
           print(c,"is the second largest number")  
           if a>=b and a>=e:
            print(a,"is the third largest number")
           elif b>=e:
             print(b,"is the third largest number")
           else:
             print(e,"is the third largest number")
         else:
           print(e, "is the second largest")
           if a>=b and a>=c:# b
             print(a,"is the third largest no")
           elif b>=c:
             print(b,"is the third largest no")
           else:
              print(c,"is the third largest no")
         
         # this below block code used for avoid if there is two duplicates skip and print next third largest
         
     else:
          print (e, "is the first greatest no") #5000
          #4030,4030,400,50,5000          
       
          if a>=b and a>=c and a>=d and a!=e:
           print(a, "is the second largest number") #4030
           if b>c and b>d  and b!=a and b!=e:
             print(b, "is the third largest number")
           elif c>d and c!=a and c!=e:
             
             print(c,"is the third largest number")#400
           else:
             print(d,"is the third largest number")
             
             
              #403,4030,4030,50,5000 
          elif b>=a and b>=c and b>=d and b!=e:
             print(b, "is the second largest number")
             if a>c and a>d and a!=e and a!=b:
              print(a,"is the third largest number")
             elif c>d and c!=e and c!=b:
              print(c,"is the third largest number")
            
             else:
                if d > a: #if b and c is same .check a and d
                 print(d,"is the  third largest number")
                else:
                 print(a,"is the  third largest number")
                 
                 
                #403,40,4030,4030,5000
          elif c>=a and c>=b and c>=d and c!=e:
              print(c, "is the second largest number")
              if  a>b and a>d and a!=c and a!=e:
               print(a,"is the third largest number")
              elif b>d and b!=c and b!=e:
               print(b," is the third largest number")             
              elif d!=e and d!=c:
                print(d,"is the third largest number")
              else:
                  if a>b: #if c and d is same .check a and b
                   print(a,"is the third largest number")  
                  else:
                   print(b,"is the third largest number")            
             
          elif d>a and d>b and d>c :
              print(d, "is the second largest number")
              if a>b and a>c:
               print(a,"is the third largest number")
              elif b>a and b>c:
               print(b," is the third largest number")
              else:
                print(c,"is the third largest number")
                
     #print(largest_first)

# %%
  fn_grtst_no(1,3,4,5,6)
# Out:
# 6 is the first greatest no
# 5 is the second largest number
# 4 is the third largest number

# %%
  fn_grtst_no(403,4030,4030,500,5000 )
# Out:
# 5000 is the first greatest no
# 4030 is the second largest number
# 500 is the  third largest number

# %%
 fn_grtst_no(4030,4030,400,500,50000)
# Out:
# 50000 is the first greatest no
# 4030 is the second largest number
# 500 is the third largest number

# %%
a=sorted(list([1,2,3,4,5]),reverse=True)[:3]
 
print(a)

a=sorted([1,2,3,4,5])[1:4]
# Out:
# [5, 4, 3]

# %%
#Check if the 2nd last number of a three digit number is divisible by 3 or not, 368, here 6 is divisible by 3. x = 368

def fn_check(a):
    
     
    
      #to find tens
      units = a%10
      print (units,":Unit")
      tens = a%100
      print(tens,"Tens")
      
      tens= tens-units
      
      sec_tens_only= round(tens/10)
      
      
      
      print (tens, ":tens")
      print (sec_tens_only, ":s")
      
      
      if sec_tens_only%3==0:
        print(sec_tens_only ,"is divisble by 3 (",a,")")
      else:
        print(sec_tens_only ,"is nt divisble by 3 (",a,")")

# %%
fn_check(368)
# Out:
# 8 :Unit
# 68 Tens
# 60 :tens
# 6 :s
# 6 is divisble by 3 ( 368 )

# %%
fn_check(398)
# Out:
# 8 :Unit
# 98 hundred
# 90 :tens
# 9 :s
# 9 is divisble by 3 ( 398 )

# %%
fn_check(378)
# Out:
# 8 :Unit
# 78 hundred
# 70 :tens
# 7 :s
# 7 is nt divisble by 3 ( 378 )

# %%
a=(60//3)%10
b=(60/3)
print(a)
print(b)
# Out:
# 0
# 20.0

# %%
#another method

def fn_check(a):
    
     
    
      #to find tens
     # sec_tens_only = (a/10) #35.7
      
       sec_tens_only = (a//10) #35
       
       sec_tens_only = (a//10)%10 #5
      
     # print (tens, ":tens")
       print (sec_tens_only, ":sec num")
      
      
       if sec_tens_only%3==0:
        print(sec_tens_only ,"is divisble by 3 (",a,")")
       else:
        print(sec_tens_only ,"is nt divisble by 3 (",a,")")

# %%
fn_check(357)
# Out:
# 5 :sec num
# 5 is nt divisble by 3 ( 357 )

# %%
    """given length and angles of a triangle try to classify the triangle into various categories:
    1. equilateral
    2. isosceles
    3. scalene
    4. acute angeled
    5. right angeled
    6. obtuse angeled"""
    
    def fn_triangle_types():
        a =int(input("enter length of the triangle:a"))
        b =int(input("enter length of the triangle:b"))
        c =int(input("enter length of the triangle:c"))
       
        d =int(input("enter angles of the triangle:d"))      
        e =int(input("enter angles of the triangle:e"))
        f= int(input("enter angles of the triangle:f"))
       
        if d+e+f==180:
          if d==e and e==f and f==d:
            if a==b and b==c and c==a: 
             print("This is equilateral traingle")
            elif a==b  and b!=c or b==c and a!=b or a==c and b!=a:            
               print("this is isosceles triangle")
            elif a!=b and b!=c and c!=a:
              print("this is scalene triangle") 
          elif d<90 and e<90 and f<90:
            print("This is acute triangle")
          elif d==90 or e==90 or f==90:
               print("This is Right angle Trianlge")
          elif d>90 or e>90 or f>90:
            print("This is obtuse Triangle")
        else:
          print("Invalid input: sum of angle must b 180 degree")

# %%
   a =int(input("enter length of the triangle:"))
   print(a)
# Out:
# 3

# %%
fn_triangle_types()
# Out:
# this is scalene triangle

# %%
        a =int(input("enter length of the triangle:a"))
        b =int(input("enter length of the triangle:b"))
        c =int(input("enter length of the triangle:b"))
       
        d =int(input("enter angles of the triangle:d"))      
        e =int(input("enter angles of the triangle:b"))
        f= int(input("enter angles of the triangle:c"))
       
        #equilateral triangle
        if d+e+f==180:
          if d==e and e==f and f==d:
            if a==b and b==c and c==a: 
             print("This is equilateral traingle")
            elif a==b  and b!=c or b==c and a!=b or a==c and b!=a:            
               print("this is isosceles triangle")
            elif a!=b and b!=c and c!=a:
              print("this is scalene triangle") 
          elif d<90 and e<90 and f<90:
            print("This is acute triangle")
          elif d==90 or e==90 or f==90:
               print("This is Right angle Trianlge")
          elif d>=90 or e>=90 or f>=90:
            print("This is obtuse Triangle")
        else:
          print("please enter the all sides of angle with sum of 180 degree")
# Out:
# this is scalene triangle
